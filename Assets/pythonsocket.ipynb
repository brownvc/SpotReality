# %%
import torch
from torch.nn import Sequential, Linear, ReLU, Softmax
import numpy as np
import json

# %%
"""
Simple Neural Net
Initially, input is features, output is action
"""
class SimpleNet:
    def __init__(self):                 
        hidden_size = 64

        self.device = torch.device("cuda")

        self.neural_net = Sequential(
            # feature size by hidden size
            Linear(11, hidden_size),
            ReLU(),
            Linear(hidden_size, hidden_size),
            ReLU(),
            # hidden size by action size
            Linear(hidden_size, 8),
            Softmax(dim=-1)
        ).to(self.device)
        self.optimizer = torch.optim.Adam(self.neural_net.parameters(), lr=1e-3)
        self.gamma = 0.999

        self.reset()


    def reset(self):
        self.ep_feats = []
        self.ep_rewards = []
        self.ep_actions = []

    def forward(self, input_feats):
        # Take as input a featurized state, output action probs
        probs = self.neural_net(input_feats.to(self.device))
        # Randomly select action according to probs
        return probs
    
    def get_action(self, input_feats):
        probs = self.forward(input_feats)
        action = np.random.choice(probs.shape[0], p=probs.cpu().detach().numpy())
        self.ep_feats.append(input_feats)
        self.ep_actions.append(action)
        return action

    def backward(self):
        print("Computing backward pass")
        log_probs = []
        
        # Get log probs for features
        for feats in self.ep_feats[1:]:
            log_probs.append(torch.log(self.forward(feats)))

        # convert log probs and actions to tensors
        log_probs = torch.stack(log_probs).to(self.device)
        actions = torch.IntTensor(self.ep_actions).to(self.device)

        # Compute discounted returns
        disc_rets = torch.zeros(actions.shape[0])
        for i in range(1, len(self.ep_rewards)):
            disc_rets[i-1] = self.discounted_return(self.ep_rewards[i:])
        disc_rets = disc_rets.to(self.device)

        # Compute loss
        # Page 328: http://www.incompleteideas.net/book/RLbook2020.pdf
        sel_log_probs = disc_rets * log_probs[np.arange(len(self.ep_actions)), self.ep_actions]
        loss = -sel_log_probs.mean()
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

        self.reset()

    def discounted_return(self, rewards):
        return np.dot(self.gamma ** np.arange(len(rewards)), rewards)

# %%
# Handle json

def convert_to_feats(response_dict):
    """Takes a response dictionary and returns tensor of features"""
    return torch.Tensor(
        (
            response_dict['feat1'],
            response_dict['feat2'],
            response_dict['feat3'],
            response_dict['feat4'],
            response_dict['feat5'],
            response_dict['feat6'],
            response_dict['feat7'],
            response_dict['feat8'],
            response_dict['feat9'],
            response_dict['feat10'],
            response_dict['feat11']
        )
    )

def handle_response(response, net: SimpleNet):
    """Take as input a websocket response from C#, return serialized data to send back"""
    # Initialize response
    instruction = ''
    action = 0
    if response is None:
        print("Response none")
        return {}
    response_dict = json.loads(response)

    # Store the reward for the previous action. 
    # Don't worry about the first one in the array, it will be ignored
    net.ep_rewards.append(response_dict['reward'])

    # Handle forward pass
    if response_dict['instruction'] == 'forward':
        features = convert_to_feats(response_dict)
        action = net.get_action(features)
        instruction = 'step'
    elif response_dict['instruction'] == 'update_weights':
        instruction = 'reset'
        last_feats = convert_to_feats(response_dict)
        net.ep_feats.append(last_feats)
        net.backward()

    json_return_dict = {
        'instruction': instruction,
        'action': action,
    }
    
    return json_return_dict

# %%
import socket
from time import time


host, port = "127.0.0.1", 25001

# SOCK_STREAM means TCP socket
sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)

neural_net = SimpleNet()
request = {
    'instruction': 'init',
    'action': 0,
}

def on_receive(message):
    print(message)

try:
    # Connect to the server and send the data
    sock.connect((host, port))

    start = 0

    while(True):
        #print(request)
        request = json.dumps(request)
        sock.sendall(request.encode("utf-8"))
        response = sock.recv(1024).decode("utf-8")
        print(f"Took {time() - start:.4f} between, that's {1/(time() - start):.2f} Hz")
        start = time()
        #print(response)
        request = handle_response(response, neural_net)
finally:
    sock.close()
# Out:
# Took 1714165817.0446 between, that's 0.00 Hz
# Took 0.0200 between, that's 50.00 Hz
# Took 0.0030 between, that's 333.38 Hz
# Took 0.0110 between, that's 90.91 Hz
# Took 0.0020 between, that's 499.86 Hz
# Took 0.0010 between, that's 997.69 Hz
# Took 0.0020 between, that's 500.69 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0020 between, that's 500.04 Hz
# Took 0.0010 between, that's 997.93 Hz
# Took 0.0010 between, that's 1000.55 Hz
# Took 0.0010 between, that's 997.93 Hz
# Took 0.0010 between, that's 1001.03 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0020 between, that's 499.92 Hz
# Took 0.0010 between, that's 1001.74 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0110 between, that's 90.91 Hz
# Took 0.0020 between, that's 499.62 Hz
# Took 0.0020 between, that's 500.16 Hz
# Took 0.0010 between, that's 1001.74 Hz
# Took 0.0010 between, that's 999.12 Hz
# Took 0.0010 between, that's 999.60 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0020 between, that's 500.22 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0020 between, that's 494.38 Hz
# Took 0.0005 between, that's 1962.71 Hz
# Took 0.0010 between, that's 1000.79 Hz
# Took 0.0010 between, that's 999.60 Hz
# Took 0.0030 between, that's 333.25 Hz
# Took 0.0110 between, that's 90.92 Hz
# Took 0.0020 between, that's 499.74 Hz
# Took 0.0010 between, that's 998.17 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0020 between, that's 500.39 Hz
# Took 0.0010 between, that's 1001.27 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0015 between, that's 657.62 Hz
# Took 0.0010 between, that's 999.60 Hz
# Took 0.0010 between, that's 1001.51 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0020 between, that's 499.80 Hz
# Took 0.0020 between, that's 499.62 Hz
# Took 0.0015 between, that's 654.03 Hz
# Took 0.0010 between, that's 1010.68 Hz
# Took 0.0100 between, that's 100.03 Hz
# Took 0.0020 between, that's 499.56 Hz
# Took 0.0020 between, that's 499.68 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0010 between, that's 1001.74 Hz
# Took 0.0020 between, that's 499.92 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0010 between, that's 997.69 Hz
# Took 0.0010 between, that's 1002.94 Hz
# Took 0.0020 between, that's 499.74 Hz
# Took 0.0010 between, that's 998.88 Hz
# Took 0.0010 between, that's 1002.94 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0005 between, that's 1953.56 Hz
# Took 0.0020 between, that's 500.10 Hz
# Took 0.0010 between, that's 999.60 Hz
# Took 0.0010 between, that's 1001.27 Hz
# Took 0.0010 between, that's 998.64 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0050 between, that's 200.11 Hz
# Took 0.0080 between, that's 124.99 Hz
# Took 0.0020 between, that's 499.50 Hz
# Took 0.0010 between, that's 999.60 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0020 between, that's 500.16 Hz
# Took 0.0010 between, that's 1001.74 Hz
# Took 0.0010 between, that's 999.60 Hz
# Took 0.0020 between, that's 499.50 Hz
# Took 0.0020 between, that's 500.33 Hz
# Took 0.0010 between, that's 1001.98 Hz
# Took 0.0120 between, that's 83.33 Hz
# Took 0.0010 between, that's 999.60 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0020 between, that's 500.22 Hz
# Took 0.0010 between, that's 985.04 Hz
# Took 0.0010 between, that's 1014.34 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0010 between, that's 999.60 Hz
# Took 0.0020 between, that's 500.51 Hz
# Took 0.0010 between, that's 1000.55 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0010 between, that's 997.69 Hz
# Took 0.0010 between, that's 1000.79 Hz
# Took 0.0010 between, that's 1001.51 Hz
# Took 0.0110 between, that's 90.91 Hz
# Took 0.0020 between, that's 499.86 Hz
# Took 0.0020 between, that's 499.80 Hz
# Took 0.0010 between, that's 1001.27 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0020 between, that's 499.86 Hz
# Took 0.0010 between, that's 997.69 Hz
# Took 0.0020 between, that's 500.04 Hz
# Took 0.0020 between, that's 500.10 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0020 between, that's 500.27 Hz
# Took 0.0115 between, that's 86.87 Hz
# Took 0.0020 between, that's 499.98 Hz
# Took 0.0020 between, that's 499.68 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0010 between, that's 998.41 Hz
# Took 0.0020 between, that's 500.57 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0020 between, that's 499.98 Hz
# Took 0.0010 between, that's 997.22 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0020 between, that's 500.33 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0011 between, that's 916.99 Hz
# Took 0.0009 between, that's 1058.63 Hz
# Took 0.0110 between, that's 90.93 Hz
# Took 0.0030 between, that's 333.17 Hz
# Took 0.0010 between, that's 1001.27 Hz
# Took 0.0015 between, that's 657.41 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0020 between, that's 500.69 Hz
# Took 0.0010 between, that's 998.41 Hz
# Took 0.0020 between, that's 500.45 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0010 between, that's 997.46 Hz
# Took 0.0015 between, that's 657.41 Hz
# Took 0.0010 between, that's 1005.11 Hz
# Took 0.0110 between, that's 90.91 Hz
# Took 0.0020 between, that's 499.62 Hz
# Took 0.0010 between, that's 1000.79 Hz
# Took 0.0010 between, that's 998.17 Hz
# Took 0.0010 between, that's 1000.79 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0010 between, that's 1000.55 Hz
# Took 0.0020 between, that's 499.44 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0010 between, that's 998.88 Hz
# Took 0.0100 between, that's 100.03 Hz
# Took 0.0020 between, that's 499.74 Hz
# Took 0.0020 between, that's 499.74 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0010 between, that's 1001.98 Hz
# Took 0.0020 between, that's 499.80 Hz
# Took 0.0010 between, that's 1000.79 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0010 between, that's 996.98 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0020 between, that's 500.45 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0010 between, that's 1000.79 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0120 between, that's 83.33 Hz
# Took 0.0020 between, that's 499.50 Hz
# Took 0.0020 between, that's 500.39 Hz
# Took 0.0010 between, that's 999.12 Hz
# Took 0.0010 between, that's 1001.51 Hz
# Took 0.0010 between, that's 997.46 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0020 between, that's 500.22 Hz
# Took 0.0010 between, that's 999.36 Hz
# Took 0.0010 between, that's 1001.03 Hz
# Took 0.0010 between, that's 998.64 Hz
# Took 0.0010 between, that's 1002.94 Hz
# Took 0.0020 between, that's 499.98 Hz
# Took 0.0105 between, that's 95.16 Hz
# Took 0.0030 between, that's 332.96 Hz
# Took 0.0010 between, that's 1000.55 Hz
# Took 0.0010 between, that's 1001.03 Hz
# Took 0.0010 between, that's 998.88 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0020 between, that's 500.10 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0010 between, that's 1001.27 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0010 between, that's 998.64 Hz
# Took 0.0010 between, that's 999.60 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0120 between, that's 83.35 Hz
# Took 0.0020 between, that's 499.98 Hz
# Took 0.0010 between, that's 998.88 Hz
# Took 0.0010 between, that's 999.12 Hz
# Took 0.0010 between, that's 992.97 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0010 between, that's 1000.79 Hz
# Took 0.0010 between, that's 999.36 Hz
# Took 0.0010 between, that's 999.36 Hz
# Took 0.0020 between, that's 499.86 Hz
# Took 0.0010 between, that's 999.60 Hz
# Took 0.0010 between, that's 1001.51 Hz
# Took 0.0010 between, that's 996.27 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0010 between, that's 1003.66 Hz
# Took 0.0110 between, that's 90.91 Hz
# Took 0.0030 between, that's 333.23 Hz
# Took 0.0018 between, that's 553.85 Hz
# Took 0.0010 between, that's 1000.55 Hz
# Took 0.0010 between, that's 999.36 Hz
# Took 0.0010 between, that's 1003.18 Hz
# Took 0.0020 between, that's 499.92 Hz
# Took 0.0010 between, that's 999.36 Hz
# Took 0.0010 between, that's 1001.27 Hz
# Took 0.0015 between, that's 682.11 Hz
# Took 0.0015 between, that's 651.49 Hz
# Took 0.0110 between, that's 90.92 Hz
# Took 0.0020 between, that's 499.62 Hz
# Took 0.0020 between, that's 499.98 Hz
# Took 0.0010 between, that's 998.41 Hz
# Took 0.0010 between, that's 1001.74 Hz
# Took 0.0020 between, that's 500.22 Hz
# Took 0.0010 between, that's 999.36 Hz
# Took 0.0020 between, that's 499.98 Hz
# Took 0.0015 between, that's 649.17 Hz
# Took 0.0010 between, that's 1002.94 Hz
# Took 0.0020 between, that's 499.26 Hz
# Took 0.0100 between, that's 100.03 Hz
# Took 0.0020 between, that's 500.27 Hz
# Took 0.0020 between, that's 499.68 Hz
# Took 0.0010 between, that's 996.51 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0010 between, that's 500.87 Hz
# Took 0.0006 between, that's 1586.35 Hz
# Took 0.0010 between, that's 1003.18 Hz
# Took 0.0010 between, that's 999.36 Hz
# Took 0.0020 between, that's 499.44 Hz
# Took 0.0010 between, that's 1002.46 Hz
# Took 0.0010 between, that's 997.69 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0010 between, that's 1002.70 Hz
# Took 0.0010 between, that's 999.12 Hz
# Took 0.0318 between, that's 31.42 Hz
# Took 0.0540 between, that's 18.52 Hz
# Took 0.0600 between, that's 16.67 Hz
# Took 0.0290 between, that's 34.48 Hz
# Took 0.0020 between, that's 499.68 Hz
# Took 0.0020 between, that's 500.27 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0020 between, that's 500.10 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0010 between, that's 996.75 Hz
# Took 0.0020 between, that's 500.57 Hz
# Took 0.0010 between, that's 999.60 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0010 between, that's 1001.03 Hz
# Took 0.0020 between, that's 499.80 Hz
# Took 0.0100 between, that's 100.01 Hz
# Took 0.0020 between, that's 499.62 Hz
# Took 0.0020 between, that's 500.04 Hz
# Took 0.0010 between, that's 1000.55 Hz
# Took 0.0010 between, that's 1000.79 Hz
# Took 0.0020 between, that's 499.44 Hz
# Took 0.0010 between, that's 1001.74 Hz
# Took 0.0010 between, that's 1001.03 Hz
# Took 0.0020 between, that's 499.62 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0100 between, that's 100.01 Hz
# Took 0.0030 between, that's 333.15 Hz
# Took 0.0010 between, that's 999.60 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0010 between, that's 1001.27 Hz
# Took 0.0020 between, that's 499.56 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0010 between, that's 1001.27 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0020 between, that's 499.56 Hz
# Took 0.0010 between, that's 1001.03 Hz
# Took 0.0110 between, that's 90.92 Hz
# Took 0.0020 between, that's 499.80 Hz
# Took 0.0010 between, that's 999.36 Hz
# Took 0.0020 between, that's 499.92 Hz
# Took 0.0010 between, that's 1000.55 Hz
# Took 0.0010 between, that's 1000.79 Hz
# Took 0.0020 between, that's 499.92 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0010 between, that's 998.88 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0020 between, that's 500.04 Hz
# Took 0.0010 between, that's 999.60 Hz
# Took 0.0100 between, that's 100.01 Hz
# Took 0.0020 between, that's 499.98 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0020 between, that's 499.68 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0010 between, that's 999.60 Hz
# Took 0.0016 between, that's 624.71 Hz
# Took 0.0014 between, that's 715.02 Hz
# Took 0.0010 between, that's 999.36 Hz
# Took 0.0010 between, that's 1000.55 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0010 between, that's 999.60 Hz
# Took 0.0010 between, that's 999.12 Hz
# Took 0.0010 between, that's 1001.27 Hz
# Took 0.0100 between, that's 100.00 Hz
# Took 0.0030 between, that's 333.20 Hz
# Took 0.0010 between, that's 1001.98 Hz
# Took 0.0020 between, that's 499.62 Hz
# Took 0.0010 between, that's 999.12 Hz
# Took 0.0005 between, that's 1910.84 Hz
# Took 0.0020 between, that's 502.25 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0020 between, that's 500.27 Hz
# Took 0.0010 between, that's 998.41 Hz
# Took 0.0010 between, that's 1000.55 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0100 between, that's 100.01 Hz
# Took 0.0020 between, that's 499.68 Hz
# Took 0.0020 between, that's 499.86 Hz
# Took 0.0010 between, that's 1001.03 Hz
# Took 0.0010 between, that's 999.12 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0020 between, that's 500.04 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0010 between, that's 1001.03 Hz
# Took 0.0010 between, that's 998.64 Hz
# Took 0.0020 between, that's 500.04 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0010 between, that's 999.12 Hz
# Took 0.0010 between, that's 1001.03 Hz
# Took 0.0120 between, that's 83.34 Hz
# Took 0.0020 between, that's 499.98 Hz
# Took 0.0020 between, that's 499.50 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0020 between, that's 499.98 Hz
# Took 0.0010 between, that's 1000.79 Hz
# Took 0.0015 between, that's 655.77 Hz
# Took 0.0010 between, that's 1011.65 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0010 between, that's 999.36 Hz
# Took 0.0020 between, that's 499.68 Hz
# Took 0.0010 between, that's 1000.79 Hz
# Took 0.0120 between, that's 83.34 Hz
# Took 0.0010 between, that's 999.60 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0020 between, that's 500.22 Hz
# Took 0.0010 between, that's 999.12 Hz
# Took 0.0010 between, that's 1000.79 Hz
# Took 0.0010 between, that's 1000.55 Hz
# Took 0.0010 between, that's 999.60 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0020 between, that's 499.80 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0015 between, that's 658.24 Hz
# Took 0.0010 between, that's 1002.70 Hz
# Took 0.0010 between, that's 1000.79 Hz
# Took 0.0010 between, that's 999.60 Hz
# Took 0.0020 between, that's 500.04 Hz
# Took 0.0105 between, that's 95.13 Hz
# Took 0.0020 between, that's 500.45 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0020 between, that's 500.04 Hz
# Took 0.0010 between, that's 999.36 Hz
# Took 0.0010 between, that's 1000.79 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0020 between, that's 499.98 Hz
# Took 0.0010 between, that's 998.41 Hz
# Took 0.0010 between, that's 1000.79 Hz
# Took 0.0100 between, that's 99.99 Hz
# Took 0.0020 between, that's 500.10 Hz
# Took 0.0010 between, that's 999.60 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0020 between, that's 500.33 Hz
# Took 0.0010 between, that's 998.88 Hz
# Took 0.0010 between, that's 1001.51 Hz
# Took 0.0010 between, that's 998.64 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0010 between, that's 1000.79 Hz
# Took 0.0020 between, that's 499.86 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0010 between, that's 1001.03 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0110 between, that's 90.91 Hz
# Took 0.0020 between, that's 499.68 Hz
# Took 0.0010 between, that's 999.12 Hz
# Took 0.0010 between, that's 1002.70 Hz
# Took 0.0010 between, that's 998.64 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0020 between, that's 500.27 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0020 between, that's 499.80 Hz
# Took 0.0010 between, that's 1000.79 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0110 between, that's 90.91 Hz
# Took 0.0020 between, that's 499.92 Hz
# Took 0.0010 between, that's 998.41 Hz
# Took 0.0020 between, that's 500.27 Hz
# Took 0.0010 between, that's 1001.03 Hz
# Took 0.0010 between, that's 998.41 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0020 between, that's 499.92 Hz
# Took 0.0010 between, that's 1001.27 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0020 between, that's 499.98 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0105 between, that's 94.89 Hz
# Took 0.0030 between, that's 333.23 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0020 between, that's 499.92 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0010 between, that's 1000.79 Hz
# Took 0.0020 between, that's 499.86 Hz
# Took 0.0010 between, that's 1001.51 Hz
# Took 0.0015 between, that's 659.38 Hz
# Took 0.0010 between, that's 1004.38 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0020 between, that's 499.98 Hz
# Took 0.0110 between, that's 90.91 Hz
# Took 0.0020 between, that's 499.92 Hz
# Took 0.0020 between, that's 499.92 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0020 between, that's 499.74 Hz
# Took 0.0010 between, that's 1001.74 Hz
# Took 0.0015 between, that's 651.29 Hz
# Took 0.0010 between, that's 1021.01 Hz
# Took 0.0020 between, that's 499.56 Hz
# Took 0.0010 between, that's 1002.22 Hz
# Took 0.0010 between, that's 998.64 Hz
# Took 0.0010 between, that's 1001.27 Hz
# Took 0.0020 between, that's 499.62 Hz
# Took 0.0095 between, that's 105.15 Hz
# Took 0.0020 between, that's 500.10 Hz
# Took 0.0010 between, that's 999.12 Hz
# Took 0.0010 between, that's 998.88 Hz
# Took 0.0020 between, that's 500.16 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0020 between, that's 499.98 Hz
# Took 0.0010 between, that's 1000.55 Hz
# Took 0.0020 between, that's 499.74 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0010 between, that's 999.36 Hz
# Took 0.0110 between, that's 90.91 Hz
# Took 0.0020 between, that's 500.10 Hz
# Took 0.0010 between, that's 1000.79 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0010 between, that's 499.86 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0010 between, that's 1000.55 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0020 between, that's 499.86 Hz
# Took 0.0010 between, that's 1000.55 Hz
# Took 0.0110 between, that's 90.91 Hz
# Took 0.0020 between, that's 499.80 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0020 between, that's 500.04 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0010 between, that's 1000.55 Hz
# Took 0.0010 between, that's 999.60 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0020 between, that's 500.10 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0110 between, that's 90.91 Hz
# Took 0.0020 between, that's 499.50 Hz
# Took 0.0020 between, that's 500.33 Hz
# Took 0.0010 between, that's 1001.27 Hz
# Took 0.0020 between, that's 499.74 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0010 between, that's 1000.79 Hz
# Took 0.0010 between, that's 999.60 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0020 between, that's 499.74 Hz
# Took 0.0010 between, that's 1001.03 Hz
# Took 0.0010 between, that's 999.12 Hz
# Took 0.0110 between, that's 90.90 Hz
# Took 0.0020 between, that's 500.27 Hz
# Took 0.0010 between, that's 999.36 Hz
# Took 0.0010 between, that's 1001.98 Hz
# Took 0.0010 between, that's 999.60 Hz
# Took 0.0010 between, that's 999.12 Hz
# Took 0.0020 between, that's 500.16 Hz
# Took 0.0010 between, that's 1000.55 Hz
# Took 0.0010 between, that's 998.88 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0010 between, that's 1000.79 Hz
# Took 0.0020 between, that's 499.86 Hz
# Took 0.0010 between, that's 999.36 Hz
# Took 0.0240 between, that's 41.67 Hz
# Took 0.0620 between, that's 16.13 Hz
# Took 0.0880 between, that's 11.36 Hz
# Took 0.0030 between, that's 333.12 Hz
# Took 0.0010 between, that's 1002.46 Hz
# Took 0.0010 between, that's 499.08 Hz
# Took 0.0010 between, that's 1001.74 Hz
# Took 0.0020 between, that's 500.39 Hz
# Took 0.0010 between, that's 998.88 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0010 between, that's 500.22 Hz
# Took 0.0010 between, that's 997.93 Hz
# Took 0.0010 between, that's 1002.46 Hz
# Took 0.0120 between, that's 83.33 Hz
# Took 0.0020 between, that's 499.74 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0010 between, that's 999.60 Hz
# Took 0.0010 between, that's 1000.55 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0010 between, that's 1000.55 Hz
# Took 0.0010 between, that's 999.60 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0010 between, that's 1001.51 Hz
# Took 0.0010 between, that's 997.93 Hz
# Took 0.0010 between, that's 1001.74 Hz
# Took 0.0020 between, that's 499.62 Hz
# Took 0.0010 between, that's 1001.27 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0010 between, that's 999.36 Hz
# Took 0.0110 between, that's 90.91 Hz
# Took 0.0020 between, that's 499.56 Hz
# Took 0.0010 between, that's 1002.22 Hz
# Took 0.0010 between, that's 993.91 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0015 between, that's 661.25 Hz
# Took 0.0010 between, that's 1001.03 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0010 between, that's 1000.79 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0020 between, that's 499.44 Hz
# Took 0.0010 between, that's 1002.22 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0100 between, that's 100.00 Hz
# Took 0.0030 between, that's 333.33 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0010 between, that's 1000.55 Hz
# Took 0.0020 between, that's 499.92 Hz
# Took 0.0010 between, that's 997.93 Hz
# Took 0.0010 between, that's 1000.55 Hz
# Took 0.0020 between, that's 500.04 Hz
# Took 0.0010 between, that's 1000.55 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0020 between, that's 500.10 Hz
# Took 0.0010 between, that's 998.64 Hz
# Took 0.0010 between, that's 1000.79 Hz
# Took 0.0100 between, that's 100.01 Hz
# Took 0.0010 between, that's 998.88 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0020 between, that's 500.04 Hz
# Took 0.0010 between, that's 1000.55 Hz
# Took 0.0010 between, that's 999.60 Hz
# Took 0.0010 between, that's 1000.55 Hz
# Took 0.0010 between, that's 1000.55 Hz
# Took 0.0010 between, that's 999.60 Hz
# Took 0.0010 between, that's 499.98 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0010 between, that's 999.36 Hz
# Took 0.0020 between, that's 500.10 Hz
# Took 0.0110 between, that's 90.91 Hz
# Took 0.0020 between, that's 499.74 Hz
# Took 0.0020 between, that's 500.16 Hz
# Took 0.0020 between, that's 499.56 Hz
# Took 0.0010 between, that's 1000.79 Hz
# Took 0.0010 between, that's 1000.55 Hz
# Took 0.0015 between, that's 658.86 Hz
# Took 0.0010 between, that's 1003.66 Hz
# Took 0.0020 between, that's 499.98 Hz
# Took 0.0010 between, that's 999.60 Hz
# Took 0.0010 between, that's 1001.51 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0020 between, that's 499.74 Hz
# Took 0.0100 between, that's 99.99 Hz
# Took 0.0010 between, that's 1000.55 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0010 between, that's 999.60 Hz
# Took 0.0010 between, that's 997.69 Hz
# Took 0.0010 between, that's 1001.98 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0010 between, that's 999.60 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0010 between, that's 999.60 Hz
# Took 0.0020 between, that's 500.16 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0105 between, that's 95.15 Hz
# Took 0.0020 between, that's 499.68 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0010 between, that's 1000.55 Hz
# Took 0.0020 between, that's 500.27 Hz
# Took 0.0010 between, that's 999.36 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0010 between, that's 999.36 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0020 between, that's 499.86 Hz
# Took 0.0010 between, that's 1000.55 Hz
# Took 0.0110 between, that's 90.91 Hz
# Took 0.0020 between, that's 499.92 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0020 between, that's 499.98 Hz
# Took 0.0010 between, that's 1001.03 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0015 between, that's 660.52 Hz
# Took 0.0010 between, that's 1001.51 Hz
# Took 0.0020 between, that's 499.50 Hz
# Took 0.0010 between, that's 1001.74 Hz
# Took 0.0010 between, that's 999.60 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0105 between, that's 95.12 Hz
# Took 0.0020 between, that's 500.69 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0010 between, that's 998.17 Hz
# Took 0.0020 between, that's 500.04 Hz
# Took 0.0010 between, that's 1001.27 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0020 between, that's 499.86 Hz
# Took 0.0010 between, that's 998.64 Hz
# Took 0.0010 between, that's 1001.51 Hz
# Took 0.0020 between, that's 499.68 Hz
# Took 0.0090 between, that's 111.13 Hz
# Took 0.0030 between, that's 333.20 Hz
# Took 0.0010 between, that's 1001.51 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0010 between, that's 999.36 Hz
# Took 0.0020 between, that's 499.80 Hz
# Took 0.0010 between, that's 1001.27 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0020 between, that's 499.62 Hz
# Took 0.0010 between, that's 1000.55 Hz
# Took 0.0010 between, that's 999.60 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0010 between, that's 1001.27 Hz
# Took 0.0100 between, that's 100.00 Hz
# Took 0.0020 between, that's 499.86 Hz
# Took 0.0020 between, that's 500.16 Hz
# Took 0.0010 between, that's 999.60 Hz
# Took 0.0010 between, that's 1000.55 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0010 between, that's 999.36 Hz
# Took 0.0020 between, that's 499.56 Hz
# Took 0.0010 between, that's 1001.51 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0010 between, that's 1000.79 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0100 between, that's 99.75 Hz
# Took 0.0020 between, that's 499.92 Hz
# Took 0.0020 between, that's 499.80 Hz
# Took 0.0010 between, that's 1000.55 Hz
# Took 0.0010 between, that's 1000.55 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0020 between, that's 499.98 Hz
# Took 0.0010 between, that's 999.12 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0020 between, that's 500.33 Hz
# Took 0.0010 between, that's 999.12 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0040 between, that's 250.03 Hz
# Took 0.0080 between, that's 125.01 Hz
# Took 0.0020 between, that's 499.74 Hz
# Took 0.0020 between, that's 499.98 Hz
# Took 0.0010 between, that's 999.60 Hz
# Took 0.0010 between, that's 1000.55 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0010 between, that's 1000.79 Hz
# Took 0.0020 between, that's 499.62 Hz
# Took 0.0025 between, that's 398.55 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0045 between, that's 221.67 Hz
# Took 0.0070 between, that's 142.86 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0020 between, that's 499.74 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0020 between, that's 499.92 Hz
# Took 0.0010 between, that's 1000.55 Hz
# Took 0.0010 between, that's 999.60 Hz
# Took 0.0020 between, that's 500.10 Hz
# Took 0.0010 between, that's 999.12 Hz
# Took 0.0010 between, that's 1000.79 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0105 between, that's 95.14 Hz
# Took 0.0020 between, that's 499.98 Hz
# Took 0.0020 between, that's 499.92 Hz
# Took 0.0010 between, that's 1000.55 Hz
# Took 0.0010 between, that's 999.36 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0020 between, that's 499.98 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0010 between, that's 998.88 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0015 between, that's 661.04 Hz
# Took 0.0010 between, that's 1002.46 Hz
# Took 0.0010 between, that's 1000.55 Hz
# Took 0.0020 between, that's 499.44 Hz
# Took 0.0095 between, that's 105.18 Hz
# Took 0.0030 between, that's 333.23 Hz
# Took 0.0010 between, that's 1001.27 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0015 between, that's 659.48 Hz
# Took 0.0010 between, that's 1004.38 Hz
# Took 0.0010 between, that's 999.60 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0020 between, that's 499.80 Hz
# Took 0.0010 between, that's 1000.55 Hz
# Took 0.0010 between, that's 999.12 Hz
# Took 0.0010 between, that's 1001.03 Hz
# Took 0.0020 between, that's 499.92 Hz
# Took 0.0110 between, that's 90.91 Hz
# Took 0.0020 between, that's 499.68 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0020 between, that's 499.98 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0010 between, that's 999.60 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0020 between, that's 500.10 Hz
# Took 0.0010 between, that's 999.60 Hz
# Took 0.0010 between, that's 1001.03 Hz
# Took 0.0010 between, that's 998.88 Hz
# Took 0.0010 between, that's 1000.79 Hz
# Took 0.0100 between, that's 99.99 Hz
# Took 0.0020 between, that's 499.92 Hz
# Took 0.0010 between, that's 1001.03 Hz
# Took 0.0010 between, that's 999.36 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0020 between, that's 500.04 Hz
# Took 0.0010 between, that's 1000.55 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0010 between, that's 999.60 Hz
# Took 0.0010 between, that's 1001.03 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0020 between, that's 499.62 Hz
# Took 0.0100 between, that's 100.02 Hz
# Took 0.0020 between, that's 499.74 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0020 between, that's 500.16 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0010 between, that's 1000.55 Hz
# Took 0.0020 between, that's 499.74 Hz
# Took 0.0010 between, that's 1001.74 Hz
# Took 0.0130 between, that's 76.92 Hz
# Took 0.0900 between, that's 11.11 Hz
# Took 0.0610 between, that's 16.39 Hz
# Took 0.0140 between, that's 71.42 Hz
# Took 0.0020 between, that's 500.04 Hz
# Took 0.0010 between, that's 999.12 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0020 between, that's 499.92 Hz
# Took 0.0010 between, that's 1000.55 Hz
# Took 0.0010 between, that's 1001.03 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0020 between, that's 499.98 Hz
# Took 0.0010 between, that's 998.88 Hz
# Took 0.0010 between, that's 1001.27 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0020 between, that's 499.80 Hz
# Took 0.0090 between, that's 111.12 Hz
# Took 0.0020 between, that's 500.04 Hz
# Took 0.0010 between, that's 999.60 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0010 between, that's 1000.79 Hz
# Took 0.0010 between, that's 1000.55 Hz
# Took 0.0020 between, that's 499.68 Hz
# Took 0.0010 between, that's 1001.27 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0020 between, that's 499.92 Hz
# Took 0.0010 between, that's 998.64 Hz
# Took 0.0010 between, that's 1001.27 Hz
# Took 0.0020 between, that's 499.98 Hz
# Took 0.0010 between, that's 999.36 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0010 between, that's 998.41 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0020 between, that's 500.16 Hz
# Took 0.0100 between, that's 100.02 Hz
# Took 0.0020 between, that's 499.68 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0020 between, that's 500.22 Hz
# Took 0.0010 between, that's 999.60 Hz
# Took 0.0010 between, that's 998.88 Hz
# Took 0.0010 between, that's 500.27 Hz
# Took 0.0010 between, that's 1001.03 Hz
# Took 0.0010 between, that's 998.17 Hz
# Took 0.0005 between, that's 1904.77 Hz
# Took 0.0020 between, that's 502.91 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0020 between, that's 500.04 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0055 between, that's 181.56 Hz
# Took 0.0085 between, that's 117.51 Hz
# Took 0.0015 between, that's 661.46 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0010 between, that's 1001.03 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0020 between, that's 499.80 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0010 between, that's 999.60 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0016 between, that's 638.89 Hz
# Took 0.0004 between, that's 2308.37 Hz
# Took 0.0020 between, that's 499.74 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0010 between, that's 999.60 Hz
# Took 0.0010 between, that's 1000.79 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0110 between, that's 90.90 Hz
# Took 0.0020 between, that's 500.45 Hz
# Took 0.0020 between, that's 499.80 Hz
# Took 0.0010 between, that's 999.60 Hz
# Took 0.0010 between, that's 999.36 Hz
# Took 0.0010 between, that's 1000.55 Hz
# Took 0.0020 between, that's 499.86 Hz
# Took 0.0020 between, that's 500.27 Hz
# Took 0.0010 between, that's 999.60 Hz
# Took 0.0010 between, that's 1000.55 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0020 between, that's 499.80 Hz
# Took 0.0130 between, that's 76.92 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0010 between, that's 999.60 Hz
# Took 0.0020 between, that's 500.04 Hz
# Took 0.0010 between, that's 1001.03 Hz
# Took 0.0010 between, that's 998.88 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0020 between, that's 499.98 Hz
# Took 0.0010 between, that's 1001.27 Hz
# Took 0.0020 between, that's 500.04 Hz
# Took 0.0010 between, that's 998.41 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0110 between, that's 90.77 Hz
# Took 0.0020 between, that's 499.62 Hz
# Took 0.0010 between, that's 1001.98 Hz
# Took 0.0020 between, that's 499.86 Hz
# Took 0.0010 between, that's 999.12 Hz
# Took 0.0010 between, that's 1001.03 Hz
# Took 0.0016 between, that's 616.27 Hz
# Took 0.0004 between, that's 2647.92 Hz
# Took 0.0020 between, that's 499.98 Hz
# Took 0.0010 between, that's 998.17 Hz
# Took 0.0010 between, that's 1000.55 Hz
# Took 0.0010 between, that's 1001.51 Hz
# Took 0.0020 between, that's 499.80 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0010 between, that's 1000.79 Hz
# Took 0.0100 between, that's 100.00 Hz
# Took 0.0020 between, that's 499.68 Hz
# Took 0.0020 between, that's 500.10 Hz
# Took 0.0020 between, that's 499.92 Hz
# Took 0.0010 between, that's 1001.03 Hz
# Took 0.0010 between, that's 999.12 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0020 between, that's 500.16 Hz
# Took 0.0010 between, that's 1000.55 Hz
# Took 0.0010 between, that's 977.01 Hz
# Took 0.0010 between, that's 998.41 Hz
# Took 0.0010 between, that's 1000.79 Hz
# Took 0.0020 between, that's 500.16 Hz
# Took 0.0012 between, that's 862.32 Hz
# Took 0.0103 between, that's 96.63 Hz
# Took 0.0020 between, that's 499.50 Hz
# Took 0.0010 between, that's 1001.51 Hz
# Took 0.0010 between, that's 1000.55 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0010 between, that's 998.88 Hz
# Took 0.0010 between, that's 1001.03 Hz
# Took 0.0010 between, that's 1000.55 Hz
# Took 0.0020 between, that's 500.10 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0010 between, that's 999.12 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0010 between, that's 999.60 Hz
# Took 0.0018 between, that's 564.28 Hz
# Took 0.0002 between, that's 4396.55 Hz
# Took 0.0020 between, that's 499.74 Hz
# Took 0.0010 between, that's 1001.03 Hz
# Took 0.0100 between, that's 99.98 Hz
# Took 0.0020 between, that's 500.33 Hz
# Took 0.0020 between, that's 499.86 Hz
# Took 0.0010 between, that's 1001.27 Hz
# Took 0.0010 between, that's 998.88 Hz
# Took 0.0010 between, that's 1001.51 Hz
# Took 0.0010 between, that's 998.64 Hz
# Took 0.0030 between, that's 333.36 Hz
# Took 0.0010 between, that's 1000.79 Hz
# Took 0.0010 between, that's 999.12 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0020 between, that's 500.16 Hz
# Took 0.0010 between, that's 999.36 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0110 between, that's 90.92 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0020 between, that's 499.86 Hz
# Took 0.0010 between, that's 998.64 Hz
# Took 0.0010 between, that's 1000.55 Hz
# Took 0.0010 between, that's 1000.55 Hz
# Took 0.0020 between, that's 499.86 Hz
# Took 0.0010 between, that's 1000.55 Hz
# Took 0.0010 between, that's 998.64 Hz
# Took 0.0010 between, that's 1001.51 Hz
# Took 0.0010 between, that's 1000.55 Hz
# Took 0.0010 between, that's 999.12 Hz
# Took 0.0015 between, that's 660.62 Hz
# Took 0.0010 between, that's 1001.51 Hz
# Took 0.0015 between, that's 658.65 Hz
# Took 0.0010 between, that's 1007.04 Hz
# Took 0.0110 between, that's 90.91 Hz
# Took 0.0020 between, that's 500.10 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0010 between, that's 1000.55 Hz
# Took 0.0010 between, that's 999.60 Hz
# Took 0.0020 between, that's 499.74 Hz
# Took 0.0010 between, that's 1001.27 Hz
# Took 0.0010 between, that's 998.64 Hz
# Took 0.0010 between, that's 1001.74 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0015 between, that's 654.64 Hz
# Took 0.0010 between, that's 974.29 Hz
# Took 0.0010 between, that's 1001.27 Hz
# Took 0.0020 between, that's 499.86 Hz
# Took 0.0010 between, that's 999.12 Hz
# Took 0.0100 between, that's 100.02 Hz
# Took 0.0020 between, that's 499.68 Hz
# Took 0.0010 between, that's 999.60 Hz
# Took 0.0010 between, that's 1000.55 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0010 between, that's 1000.55 Hz
# Took 0.0020 between, that's 500.04 Hz
# Took 0.0010 between, that's 999.36 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0010 between, that's 1000.55 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0016 between, that's 623.22 Hz
# Took 0.0004 between, that's 2526.69 Hz
# Took 0.0010 between, that's 1001.27 Hz
# Took 0.0110 between, that's 90.91 Hz
# Took 0.0025 between, that's 408.09 Hz
# Took 0.0005 between, that's 1822.82 Hz
# Took 0.0020 between, that's 499.68 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0010 between, that's 1000.55 Hz
# Took 0.0020 between, that's 500.04 Hz
# Took 0.0010 between, that's 998.88 Hz
# Took 0.0105 between, that's 95.12 Hz
# Took 0.0030 between, that's 333.25 Hz
# Took 0.0010 between, that's 999.60 Hz
# Took 0.0010 between, that's 998.17 Hz
# Took 0.0010 between, that's 1002.70 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0020 between, that's 499.68 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0020 between, that's 499.92 Hz
# Took 0.0010 between, that's 1000.55 Hz
# Took 0.0030 between, that's 333.17 Hz
# Took 0.0010 between, that's 1001.74 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0010 between, that's 999.60 Hz
# Took 0.0110 between, that's 90.92 Hz
# Took 0.0020 between, that's 499.56 Hz
# Took 0.0010 between, that's 999.36 Hz
# Took 0.0010 between, that's 1002.22 Hz
# Took 0.0020 between, that's 500.04 Hz
# Took 0.0010 between, that's 998.88 Hz
# Took 0.0020 between, that's 500.33 Hz
# Took 0.0010 between, that's 999.36 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0020 between, that's 499.86 Hz
# Took 0.0010 between, that's 999.36 Hz
# Took 0.0010 between, that's 1000.79 Hz
# Took 0.0110 between, that's 90.71 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0020 between, that's 499.92 Hz
# Took 0.0010 between, that's 998.88 Hz
# Took 0.0010 between, that's 1001.03 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0020 between, that's 499.86 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0010 between, that's 998.88 Hz
# Took 0.0020 between, that's 500.10 Hz
# Took 0.0100 between, that's 100.01 Hz
# Took 0.0020 between, that's 499.80 Hz
# Took 0.0010 between, that's 1000.55 Hz
# Took 0.0010 between, that's 999.36 Hz
# Took 0.0020 between, that's 500.22 Hz
# Took 0.0010 between, that's 999.60 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0010 between, that's 999.60 Hz
# Took 0.0020 between, that's 500.10 Hz
# Took 0.0010 between, that's 1001.03 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0100 between, that's 100.00 Hz
# Took 0.0020 between, that's 499.68 Hz
# Took 0.0010 between, that's 1000.79 Hz
# Took 0.0020 between, that's 499.86 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0010 between, that's 1000.79 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0030 between, that's 333.23 Hz
# Took 0.0010 between, that's 1001.03 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0110 between, that's 90.91 Hz
# Took 0.0020 between, that's 499.56 Hz
# Took 0.0020 between, that's 500.16 Hz
# Took 0.0010 between, that's 999.60 Hz
# Took 0.0010 between, that's 1001.03 Hz
# Took 0.0010 between, that's 998.88 Hz
# Took 0.0015 between, that's 658.34 Hz
# Took 0.0010 between, that's 1006.79 Hz
# Took 0.0010 between, that's 999.36 Hz
# Took 0.0010 between, that's 1000.79 Hz
# Took 0.0020 between, that's 499.92 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0010 between, that's 999.36 Hz
# Took 0.0340 between, that's 29.41 Hz
# Took 0.0800 between, that's 12.50 Hz
# Took 0.0380 between, that's 26.32 Hz
# Took 0.0270 between, that's 37.04 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0020 between, that's 499.86 Hz
# Took 0.0010 between, that's 1000.55 Hz
# Took 0.0010 between, that's 999.12 Hz
# Took 0.0010 between, that's 1000.55 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0020 between, that's 499.98 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0113 between, that's 88.80 Hz
# Took 0.0020 between, that's 499.38 Hz
# Took 0.0020 between, that's 499.74 Hz
# Took 0.0010 between, that's 1002.70 Hz
# Took 0.0010 between, that's 999.60 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0020 between, that's 500.22 Hz
# Took 0.0010 between, that's 999.36 Hz
# Took 0.0010 between, that's 1000.55 Hz
# Took 0.0010 between, that's 1000.55 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0010 between, that's 999.60 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0110 between, that's 90.91 Hz
# Took 0.0020 between, that's 499.74 Hz
# Took 0.0010 between, that's 999.36 Hz
# Took 0.0010 between, that's 1000.79 Hz
# Took 0.0010 between, that's 1000.55 Hz
# Took 0.0010 between, that's 998.64 Hz
# Took 0.0016 between, that's 638.89 Hz
# Took 0.0009 between, that's 1057.83 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0010 between, that's 999.60 Hz
# Took 0.0020 between, that's 499.92 Hz
# Took 0.0010 between, that's 1000.55 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0110 between, that's 90.89 Hz
# Took 0.0020 between, that's 499.98 Hz
# Took 0.0010 between, that's 1001.51 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0010 between, that's 1000.55 Hz
# Took 0.0020 between, that's 499.50 Hz
# Took 0.0010 between, that's 1001.03 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0010 between, that's 999.36 Hz
# Took 0.0010 between, that's 1001.98 Hz
# Took 0.0010 between, that's 999.60 Hz
# Took 0.0012 between, that's 805.51 Hz
# Took 0.0008 between, that's 1317.72 Hz
# Took 0.0110 between, that's 90.91 Hz
# Took 0.0020 between, that's 500.27 Hz
# Took 0.0010 between, that's 999.12 Hz
# Took 0.0018 between, that's 561.19 Hz
# Took 0.0002 between, that's 4593.98 Hz
# Took 0.0020 between, that's 499.86 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0010 between, that's 1001.03 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0010 between, that's 999.36 Hz
# Took 0.0020 between, that's 499.62 Hz
# Took 0.0010 between, that's 1001.98 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0105 between, that's 95.14 Hz
# Took 0.0020 between, that's 499.92 Hz
# Took 0.0020 between, that's 499.68 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0010 between, that's 1001.03 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0020 between, that's 499.98 Hz
# Took 0.0010 between, that's 998.88 Hz
# Took 0.0010 between, that's 1001.27 Hz
# Took 0.0010 between, that's 1000.79 Hz
# Took 0.0020 between, that's 499.02 Hz
# Took 0.0020 between, that's 500.75 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0105 between, that's 95.14 Hz
# Took 0.0020 between, that's 499.98 Hz
# Took 0.0020 between, that's 499.68 Hz
# Took 0.0010 between, that's 1001.03 Hz
# Took 0.0010 between, that's 999.12 Hz
# Took 0.0010 between, that's 1000.55 Hz
# Took 0.0010 between, that's 999.60 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0020 between, that's 499.92 Hz
# Took 0.0100 between, that's 100.02 Hz
# Took 0.0030 between, that's 332.96 Hz
# Took 0.0020 between, that's 500.39 Hz
# Took 0.0010 between, that's 1001.51 Hz
# Took 0.0020 between, that's 499.68 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0020 between, that's 500.10 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0100 between, that's 100.00 Hz
# Took 0.0030 between, that's 333.36 Hz
# Took 0.0020 between, that's 499.86 Hz
# Took 0.0010 between, that's 500.04 Hz
# Took 0.0010 between, that's 998.88 Hz
# Took 0.0020 between, that's 500.10 Hz
# Took 0.0010 between, that's 1000.79 Hz
# Took 0.0010 between, that's 998.88 Hz
# Took 0.0115 between, that's 86.86 Hz
# Took 0.0020 between, that's 499.86 Hz
# Took 0.0020 between, that's 499.92 Hz
# Took 0.0020 between, that's 499.98 Hz
# Took 0.0010 between, that's 1001.03 Hz
# Took 0.0020 between, that's 499.92 Hz
# Took 0.0010 between, that's 998.88 Hz
# Took 0.0015 between, that's 660.00 Hz
# Took 0.0020 between, that's 500.22 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0120 between, that's 83.33 Hz
# Took 0.0020 between, that's 500.10 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0020 between, that's 499.92 Hz
# Took 0.0010 between, that's 999.36 Hz
# Took 0.0020 between, that's 500.33 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0010 between, that's 997.22 Hz
# Took 0.0020 between, that's 500.51 Hz
# Took 0.0010 between, that's 999.60 Hz
# Took 0.0010 between, that's 1000.55 Hz
# Took 0.0120 between, that's 83.34 Hz
# Took 0.0020 between, that's 499.86 Hz
# Took 0.0010 between, that's 999.60 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0020 between, that's 499.92 Hz
# Took 0.0020 between, that's 500.16 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0010 between, that's 1000.55 Hz
# Took 0.0020 between, that's 499.86 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0010 between, that's 1001.27 Hz
# Took 0.0010 between, that's 999.60 Hz
# Took 0.0020 between, that's 499.86 Hz
# Took 0.0110 between, that's 90.91 Hz
# Took 0.0030 between, that's 333.33 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0020 between, that's 499.68 Hz
# Took 0.0010 between, that's 999.60 Hz
# Took 0.0010 between, that's 1001.27 Hz
# Took 0.0020 between, that's 499.80 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0010 between, that's 999.60 Hz
# Took 0.0020 between, that's 500.27 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0010 between, that's 999.36 Hz
# Took 0.0010 between, that's 1000.79 Hz
# ...
# Took 0.0020 between, that's 499.74 Hz
# Took 0.0020 between, that's 499.68 Hz
# Took 0.0010 between, that's 1000.79 Hz
# Took 0.0020 between, that's 499.32 Hz
# Took 0.0106 between, that's 94.06 Hz
# Took 0.0026 between, that's 385.26 Hz
# Took 0.0010 between, that's 1001.27 Hz
# Took 0.0020 between, that's 499.98 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0020 between, that's 499.98 Hz
# Took 0.0020 between, that's 500.16 Hz
# Took 0.0010 between, that's 999.12 Hz
# Took 0.0020 between, that's 499.86 Hz
# Took 0.0050 between, that's 200.01 Hz
# Took 0.0090 between, that's 111.11 Hz
# Took 0.0020 between, that's 500.10 Hz
# Took 0.0020 between, that's 499.74 Hz
# Took 0.0020 between, that's 500.27 Hz
# Took 0.0020 between, that's 499.44 Hz
# Took 0.0010 between, that's 1001.74 Hz
# Took 0.0020 between, that's 500.22 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0015 between, that's 645.87 Hz
# Took 0.0105 between, that's 94.99 Hz
# Took 0.0020 between, that's 499.92 Hz
# Took 0.0020 between, that's 499.56 Hz
# Took 0.0020 between, that's 500.16 Hz
# Took 0.0020 between, that's 500.39 Hz
# Took 0.0020 between, that's 499.62 Hz
# Took 0.0010 between, that's 1001.51 Hz
# Took 0.0020 between, that's 499.62 Hz
# Took 0.0110 between, that's 90.92 Hz
# Took 0.0020 between, that's 500.39 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0020 between, that's 499.62 Hz
# Took 0.0010 between, that's 1000.55 Hz
# Took 0.0020 between, that's 500.39 Hz
# Took 0.0010 between, that's 998.41 Hz
# Took 0.0010 between, that's 999.60 Hz
# Took 0.0020 between, that's 500.04 Hz
# Took 0.0010 between, that's 1002.46 Hz
# Took 0.0020 between, that's 500.10 Hz
# Took 0.0110 between, that's 90.90 Hz
# Took 0.0020 between, that's 500.22 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0020 between, that's 499.92 Hz
# Took 0.0010 between, that's 1000.55 Hz
# Took 0.0020 between, that's 499.86 Hz
# Took 0.0020 between, that's 500.22 Hz
# Took 0.0010 between, that's 997.46 Hz
# Took 0.0010 between, that's 1002.70 Hz
# Took 0.0020 between, that's 499.80 Hz
# Took 0.0105 between, that's 95.00 Hz
# Took 0.0010 between, that's 1002.94 Hz
# Took 0.0020 between, that's 499.44 Hz
# Took 0.0020 between, that's 500.33 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0020 between, that's 499.92 Hz
# Took 0.0010 between, that's 999.36 Hz
# Took 0.0010 between, that's 1001.03 Hz
# Took 0.0020 between, that's 499.86 Hz
# Took 0.0010 between, that's 1000.79 Hz
# Took 0.0020 between, that's 499.92 Hz
# Took 0.0010 between, that's 999.36 Hz
# Took 0.0110 between, that's 90.83 Hz
# Took 0.0020 between, that's 499.80 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0020 between, that's 500.22 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0020 between, that's 499.92 Hz
# Took 0.0020 between, that's 500.27 Hz
# Took 0.0010 between, that's 996.98 Hz
# Took 0.0010 between, that's 1002.94 Hz
# Took 0.0020 between, that's 499.68 Hz
# Took 0.0010 between, that's 998.64 Hz
# Took 0.0339 between, that's 29.46 Hz
# Took 0.0662 between, that's 15.11 Hz
# Took 0.0594 between, that's 16.83 Hz
# Took 0.0200 between, that's 49.97 Hz
# Took 0.0020 between, that's 500.10 Hz
# Took 0.0020 between, that's 499.80 Hz
# Took 0.0020 between, that's 499.62 Hz
# Took 0.0020 between, that's 500.10 Hz
# Took 0.0116 between, that's 86.11 Hz
# Took 0.0020 between, that's 500.27 Hz
# Took 0.0030 between, that's 333.04 Hz
# Took 0.0020 between, that's 500.63 Hz
# Took 0.0020 between, that's 499.80 Hz
# Took 0.0010 between, that's 1000.79 Hz
# Took 0.0020 between, that's 499.80 Hz
# Took 0.0110 between, that's 90.83 Hz
# Took 0.0030 between, that's 333.30 Hz
# Took 0.0020 between, that's 499.62 Hz
# Took 0.0010 between, that's 1001.74 Hz
# Took 0.0020 between, that's 499.86 Hz
# Took 0.0010 between, that's 1001.51 Hz
# Took 0.0020 between, that's 499.62 Hz
# Took 0.0010 between, that's 1001.03 Hz
# Took 0.0010 between, that's 1000.55 Hz
# Took 0.0020 between, that's 499.80 Hz
# Took 0.0110 between, that's 90.90 Hz
# Took 0.0021 between, that's 484.22 Hz
# Took 0.0010 between, that's 998.41 Hz
# Took 0.0020 between, that's 500.27 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0010 between, that's 1002.94 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0020 between, that's 499.74 Hz
# Took 0.0010 between, that's 997.93 Hz
# Took 0.0020 between, that's 500.51 Hz
# Took 0.0010 between, that's 997.93 Hz
# Took 0.0010 between, that's 1002.70 Hz
# Took 0.0110 between, that's 90.82 Hz
# Took 0.0020 between, that's 499.56 Hz
# Took 0.0011 between, that's 870.01 Hz
# Took 0.0020 between, that's 502.01 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0020 between, that's 499.92 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0020 between, that's 499.92 Hz
# Took 0.0011 between, that's 917.19 Hz
# Took 0.0010 between, that's 1006.31 Hz
# Took 0.0020 between, that's 499.80 Hz
# Took 0.0100 between, that's 99.89 Hz
# Took 0.0020 between, that's 500.16 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0017 between, that's 581.90 Hz
# Took 0.0020 between, that's 500.33 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0010 between, that's 1001.98 Hz
# Took 0.0020 between, that's 499.68 Hz
# Took 0.0020 between, that's 499.86 Hz
# Took 0.0020 between, that's 499.98 Hz
# Took 0.0010 between, that's 1001.98 Hz
# Took 0.0110 between, that's 90.89 Hz
# Took 0.0020 between, that's 500.51 Hz
# Took 0.0010 between, that's 999.12 Hz
# Took 0.0020 between, that's 500.22 Hz
# Took 0.0010 between, that's 1000.55 Hz
# Took 0.0020 between, that's 499.74 Hz
# Took 0.0010 between, that's 999.60 Hz
# Took 0.0020 between, that's 500.22 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0020 between, that's 499.86 Hz
# Took 0.0100 between, that's 99.88 Hz
# Took 0.0030 between, that's 333.41 Hz
# Took 0.0010 between, that's 998.88 Hz
# Took 0.0020 between, that's 500.16 Hz
# Took 0.0010 between, that's 999.12 Hz
# Took 0.0020 between, that's 499.68 Hz
# Took 0.0020 between, that's 500.87 Hz
# Took 0.0020 between, that's 499.50 Hz
# Took 0.0100 between, that's 99.99 Hz
# Took 0.0023 between, that's 436.27 Hz
# Took 0.0020 between, that's 499.98 Hz
# Took 0.0010 between, that's 998.17 Hz
# Took 0.0020 between, that's 500.33 Hz
# Took 0.0010 between, that's 999.12 Hz
# Took 0.0010 between, that's 1001.27 Hz
# Took 0.0020 between, that's 499.86 Hz
# Took 0.0020 between, that's 500.10 Hz
# Took 0.0040 between, that's 250.02 Hz
# Took 0.0090 between, that's 111.11 Hz
# Took 0.0020 between, that's 500.04 Hz
# Took 0.0010 between, that's 1000.55 Hz
# Took 0.0020 between, that's 500.04 Hz
# Took 0.0020 between, that's 508.22 Hz
# Took 0.0010 between, that's 999.36 Hz
# Took 0.0020 between, that's 500.33 Hz
# Took 0.0105 between, that's 95.08 Hz
# Took 0.0020 between, that's 500.22 Hz
# Took 0.0020 between, that's 499.98 Hz
# Took 0.0020 between, that's 500.16 Hz
# Took 0.0020 between, that's 499.80 Hz
# Took 0.0020 between, that's 500.22 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0110 between, that's 90.90 Hz
# Took 0.0020 between, that's 500.10 Hz
# Took 0.0020 between, that's 500.10 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0020 between, that's 499.44 Hz
# Took 0.0010 between, that's 1001.98 Hz
# Took 0.0020 between, that's 500.16 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0020 between, that's 500.10 Hz
# Took 0.0100 between, that's 99.80 Hz
# Took 0.0020 between, that's 500.39 Hz
# Took 0.0010 between, that's 999.36 Hz
# Took 0.0020 between, that's 499.68 Hz
# Took 0.0010 between, that's 1001.74 Hz
# Took 0.0020 between, that's 499.98 Hz
# Took 0.0010 between, that's 966.88 Hz
# Took 0.0020 between, that's 501.89 Hz
# Took 0.0020 between, that's 500.04 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0110 between, that's 90.77 Hz
# Took 0.0020 between, that's 501.23 Hz
# Took 0.0010 between, that's 1001.74 Hz
# Took 0.0019 between, that's 523.37 Hz
# Took 0.0010 between, that's 1000.55 Hz
# Took 0.0020 between, that's 499.92 Hz
# Took 0.0010 between, that's 997.93 Hz
# Took 0.0020 between, that's 499.80 Hz
# Took 0.0010 between, that's 1003.18 Hz
# Took 0.0016 between, that's 625.83 Hz
# Took 0.0110 between, that's 90.94 Hz
# Took 0.0020 between, that's 499.92 Hz
# Took 0.0020 between, that's 499.98 Hz
# Took 0.0010 between, that's 1000.79 Hz
# Took 0.0020 between, that's 499.50 Hz
# Took 0.0010 between, that's 1001.51 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0020 between, that's 499.98 Hz
# Took 0.0010 between, that's 998.88 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0020 between, that's 500.39 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0110 between, that's 90.89 Hz
# Took 0.0030 between, that's 333.44 Hz
# Took 0.0020 between, that's 500.22 Hz
# Took 0.0010 between, that's 998.88 Hz
# Took 0.0020 between, that's 500.27 Hz
# Took 0.0010 between, that's 998.88 Hz
# Took 0.0020 between, that's 500.33 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0100 between, that's 100.38 Hz
# Took 0.0029 between, that's 348.60 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0010 between, that's 999.60 Hz
# Took 0.0010 between, that's 999.60 Hz
# Took 0.0010 between, that's 1000.55 Hz
# Took 0.0020 between, that's 499.98 Hz
# Took 0.0020 between, that's 499.80 Hz
# Took 0.0010 between, that's 1001.03 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0020 between, that's 499.86 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0110 between, that's 90.89 Hz
# Took 0.0020 between, that's 500.57 Hz
# Took 0.0020 between, that's 499.98 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0020 between, that's 499.44 Hz
# Took 0.0010 between, that's 1001.27 Hz
# Took 0.0020 between, that's 499.68 Hz
# Took 0.0010 between, that's 500.63 Hz
# Took 0.0010 between, that's 998.88 Hz
# Took 0.0020 between, that's 499.86 Hz
# Took 0.0100 between, that's 100.01 Hz
# Took 0.0020 between, that's 499.50 Hz
# Took 0.0020 between, that's 499.98 Hz
# Took 0.0020 between, that's 500.75 Hz
# Took 0.0010 between, that's 998.88 Hz
# Took 0.0020 between, that's 500.16 Hz
# Took 0.0020 between, that's 499.80 Hz
# Took 0.0010 between, that's 1000.55 Hz
# Took 0.0110 between, that's 90.91 Hz
# Took 0.0020 between, that's 500.22 Hz
# Took 0.0010 between, that's 998.88 Hz
# Took 0.0020 between, that's 500.16 Hz
# Took 0.0010 between, that's 999.60 Hz
# Took 0.0020 between, that's 500.22 Hz
# Took 0.0010 between, that's 1000.55 Hz
# Took 0.0020 between, that's 499.74 Hz
# Took 0.0010 between, that's 996.98 Hz
# Took 0.0020 between, that's 500.63 Hz
# Took 0.0280 between, that's 35.72 Hz
# Took 0.0631 between, that's 15.84 Hz
# Took 0.0550 between, that's 18.17 Hz
# Took 0.0347 between, that's 28.83 Hz
# Took 0.0020 between, that's 500.57 Hz
# Took 0.0020 between, that's 499.86 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0020 between, that's 499.92 Hz
# Took 0.0010 between, that's 1001.03 Hz
# Took 0.0020 between, that's 499.86 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0020 between, that's 499.92 Hz
# Took 0.0020 between, that's 499.38 Hz
# Took 0.0140 between, that's 71.45 Hz
# Took 0.0019 between, that's 518.84 Hz
# Took 0.0020 between, that's 499.98 Hz
# Took 0.0020 between, that's 500.22 Hz
# Took 0.0020 between, that's 499.98 Hz
# Took 0.0020 between, that's 500.16 Hz
# Took 0.0017 between, that's 597.99 Hz
# Took 0.0103 between, that's 96.72 Hz
# Took 0.0020 between, that's 500.16 Hz
# Took 0.0020 between, that's 499.80 Hz
# Took 0.0010 between, that's 1000.55 Hz
# Took 0.0020 between, that's 499.92 Hz
# Took 0.0020 between, that's 500.22 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0020 between, that's 500.16 Hz
# Took 0.0010 between, that's 999.36 Hz
# Took 0.0020 between, that's 499.74 Hz
# Took 0.0010 between, that's 1000.55 Hz
# Took 0.0020 between, that's 499.98 Hz
# Took 0.0110 between, that's 90.90 Hz
# Took 0.0020 between, that's 500.04 Hz
# Took 0.0020 between, that's 500.10 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0010 between, that's 999.60 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0020 between, that's 500.16 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0020 between, that's 499.92 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0110 between, that's 90.90 Hz
# Took 0.0020 between, that's 499.44 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0020 between, that's 499.26 Hz
# Took 0.0010 between, that's 1003.42 Hz
# Took 0.0020 between, that's 499.68 Hz
# Took 0.0010 between, that's 1000.55 Hz
# Took 0.0020 between, that's 499.50 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0010 between, that's 1002.94 Hz
# Took 0.0020 between, that's 499.74 Hz
# Took 0.0100 between, that's 99.90 Hz
# Took 0.0020 between, that's 500.27 Hz
# Took 0.0018 between, that's 565.80 Hz
# Took 0.0020 between, that's 500.10 Hz
# Took 0.0030 between, that's 333.15 Hz
# Took 0.0285 between, that's 35.07 Hz
# Took 0.0030 between, that's 333.23 Hz
# Took 0.0020 between, that's 499.74 Hz
# Took 0.0120 between, that's 83.25 Hz
# Took 0.0030 between, that's 333.49 Hz
# Took 0.0030 between, that's 332.88 Hz
# Took 0.0020 between, that's 500.87 Hz
# Took 0.0010 between, that's 996.75 Hz
# Took 0.0020 between, that's 500.87 Hz
# Took 0.0020 between, that's 499.86 Hz
# Took 0.0010 between, that's 1001.03 Hz
# Took 0.0020 between, that's 499.86 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0110 between, that's 90.91 Hz
# Took 0.0030 between, that's 333.23 Hz
# Took 0.0020 between, that's 499.74 Hz
# Took 0.0020 between, that's 500.10 Hz
# Took 0.0010 between, that's 1001.51 Hz
# Took 0.0020 between, that's 499.62 Hz
# Took 0.0010 between, that's 1001.27 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0020 between, that's 500.10 Hz
# Took 0.0010 between, that's 999.36 Hz
# Took 0.0020 between, that's 499.92 Hz
# Took 0.0010 between, that's 1000.55 Hz
# Took 0.0110 between, that's 90.90 Hz
# Took 0.0020 between, that's 500.33 Hz
# Took 0.0020 between, that's 499.74 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0010 between, that's 1000.79 Hz
# Took 0.0020 between, that's 499.86 Hz
# Took 0.0010 between, that's 999.60 Hz
# Took 0.0010 between, that's 1000.55 Hz
# Took 0.0020 between, that's 500.04 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0020 between, that's 498.91 Hz
# Took 0.0010 between, that's 1002.94 Hz
# Took 0.0010 between, that's 1000.07 Hz
# Took 0.0020 between, that's 500.04 Hz
# Took 0.0100 between, that's 100.00 Hz
# Took 0.0030 between, that's 333.30 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0020 between, that's 499.98 Hz
# Took 0.0010 between, that's 997.93 Hz
# Took 0.0010 between, that's 1001.98 Hz
# Took 0.0020 between, that's 500.22 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0020 between, that's 499.98 Hz
# Took 0.0010 between, that's 999.36 Hz
# Took 0.0020 between, that's 499.80 Hz
# Took 0.0150 between, that's 66.67 Hz
# Took 0.0010 between, that's 1001.74 Hz
# Took 0.0020 between, that's 499.68 Hz
# Took 0.0020 between, that's 500.10 Hz
# Took 0.0010 between, that's 1000.55 Hz
# Took 0.0020 between, that's 499.56 Hz
# Took 0.0020 between, that's 500.27 Hz
# Took 0.0100 between, that's 100.00 Hz
# Took 0.0020 between, that's 500.33 Hz
# Took 0.0020 between, that's 500.10 Hz
# Took 0.0020 between, that's 499.62 Hz
# Took 0.0020 between, that's 500.16 Hz
# Took 0.0010 between, that's 1000.55 Hz
# Took 0.0020 between, that's 499.86 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Took 0.0100 between, that's 100.00 Hz
# Took 0.0020 between, that's 499.68 Hz
# Took 0.0020 between, that's 499.86 Hz
# Took 0.0010 between, that's 1001.27 Hz
# Took 0.0030 between, that's 333.41 Hz
# Took 0.0010 between, that's 999.60 Hz
# Took 0.0020 between, that's 499.86 Hz
# Took 0.0010 between, that's 1000.79 Hz
# Took 0.0020 between, that's 499.86 Hz
# Took 0.0010 between, that's 1000.79 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0020 between, that's 499.74 Hz
# Took 0.0100 between, that's 100.00 Hz
# Took 0.0030 between, that's 333.36 Hz
# Took 0.0020 between, that's 499.92 Hz
# Took 0.0030 between, that's 333.20 Hz
# Took 0.0030 between, that's 333.38 Hz
# Took 0.0020 between, that's 500.22 Hz
# Took 0.0010 between, that's 999.83 Hz
# Took 0.0010 between, that's 1000.31 Hz
# Computing backward pass
